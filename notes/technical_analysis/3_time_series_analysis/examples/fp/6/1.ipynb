# %%
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("TSLA.csv")
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 1  2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 2  2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 3  2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000
# 4  2015-07-16  52.844002  53.439999  52.632000  53.335999  53.335999   8080000

# %%
df = df[["Date", "Close"]]
df = df.rename(columns={"Date": "ds", "Close": "y"})
last = df[len(df)-20:]
last
# Out:
#               ds           y
# 1239  2020-06-11  194.567993
# 1240  2020-06-12  187.056000
# 1241  2020-06-15  198.179993
# 1242  2020-06-16  196.425995
# 1243  2020-06-17  198.358002
# 1244  2020-06-18  200.792007
# 1245  2020-06-19  200.179993
# 1246  2020-06-22  198.863998
# 1247  2020-06-23  200.356003
# 1248  2020-06-24  192.169998
# 1249  2020-06-25  197.195999
# 1250  2020-06-26  191.947998
# 1251  2020-06-29  201.869995
# 1252  2020-06-30  215.962006
# 1253  2020-07-01  223.925995
# 1254  2020-07-02  241.731995
# 1255  2020-07-06  274.316010
# 1256  2020-07-07  277.971985
# 1257  2020-07-08  273.175995
# 1258  2020-07-09  278.855988

# %%
df = df[:-20]
df
# Out:
#               ds           y
# 0     2015-07-10   51.830002
# 1     2015-07-13   52.431999
# 2     2015-07-14   53.130001
# 3     2015-07-15   52.627998
# 4     2015-07-16   53.335999
# ...          ...         ...
# 1214  2020-05-06  156.516006
# 1215  2020-05-07  156.007996
# 1216  2020-05-08  163.884003
# 1217  2020-05-11  162.257996
# 1218  2020-05-12  161.882004
#
# [1219 rows x 2 columns]

# %%
fbp = Prophet(daily_seasonality=True)
fbp.fit(df)
future = fbp.make_future_dataframe(periods=365)
forecast = fbp.predict(future)
# Out:
# Initial log joint probability = -54.1525
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2671.22    0.00324814       334.824           1           1      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       2732.38     0.0267924       271.869           1           1      244
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       2771.29     0.0321496       349.809           1           1      358
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399        2807.9     0.0129668       412.861           1           1      476
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       2815.15   0.000364044       94.6858           1           1      597
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      513       2815.51    7.5829e-05       123.852   5.352e-07       0.001      664  LS failed, Hessian reset
#      564       2816.39   0.000122049       156.783   1.279e-06       0.001      766  LS failed, Hessian reset
#      599       2816.72     0.0119046        252.33           1           1      812
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      602       2816.83   8.69762e-05       142.999   5.004e-07       0.001      850  LS failed, Hessian reset
#      650       2817.56   5.43774e-05        88.387   7.378e-07       0.001      946  LS failed, Hessian reset
#      679       2817.69   0.000620273       75.3107   7.428e-06       0.001     1021  LS failed, Hessian reset
#      699       2817.78    0.00106186       112.472           1           1     1041
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      742       2820.01   6.75087e-05       116.027   4.265e-07       0.001     1150  LS failed, Hessian reset
#      799       2822.83   0.000600673       196.186           1           1     1222
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       2823.83   0.000386108       112.059      0.2413           1     1351
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      932       2825.24   5.68617e-05       107.657   6.236e-07       0.001     1427  LS failed, Hessian reset
#      999       2826.41    0.00323004       335.786           1           1     1506
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       2827.35   0.000578738       129.208      0.7896      0.7896     1646
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199        2828.4   2.03106e-05       59.2963      0.3471           1     1780
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       2829.25     0.0043055        97.001           1           1     1893
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        2830.7   0.000511516       215.055    5.27e-06       0.001     2061  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       2831.24   9.78216e-05       72.0382       2.598      0.6525     2190
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       2831.56     0.0015966       59.1876           1           1     2303
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1618       2831.67   5.74533e-05       99.5997   3.964e-07       0.001     2379  LS failed, Hessian reset
#     1699       2831.85   1.08687e-05       91.8164       0.872       0.872     2475
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1743       2831.88   4.77821e-06       73.8637   6.636e-08       0.001     2566  LS failed, Hessian reset
#     1799       2831.88   2.65366e-05       71.1597           1           1     2633
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1829       2831.88   1.90506e-07       67.4962      0.2318           1     2670
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
plot_plotly(fbp, forecast)

# %%
# Show current pred
forecast[forecast.ds == "2020-07-08"]["yhat"]
# Out:
# 1275    151.970493
# Name: yhat, dtype: float64

# %%
# Show current real value
last[last.ds == "2020-07-08"]["y"]
# Out:
# 1257    273.175995
# Name: y, dtype: float64
